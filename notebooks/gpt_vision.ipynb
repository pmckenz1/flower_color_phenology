# %%
import pandas as pd
import numpy as np
from openai import OpenAI
import time

client = OpenAI(
    api_key='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'
)

# %%
inat_data = pd.read_csv('../data/combined_raw_inaturalist_export.csv')
# Out:
# /var/folders/qh/c7rwx84921n2kznn09zb2pnh0000gn/T/ipykernel_29600/2374178123.py:1: DtypeWarning: Columns (0,5,14,18,19,20,29,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   inat_data = pd.read_csv('../data/combined_raw_inaturalist_export.csv')

# %% [markdown]
# # Filter down the data to only include species names that are two words, where the second word isn't 'x' (e.g. from a hybrid)

# %%
binoms = [' '.join(str(i).split(' ')[:2]) for i in inat_data.scientific_name]

# %%
inat_data['binomial'] = binoms

# %%
inat_data = inat_data[~np.array([len(i.split(' ')) == 1 for i in inat_data.binomial])] # filter out single-word names

# %%
inat_data = inat_data[~np.array([i.split(' ')[1] == 'x' for i in inat_data.binomial])] # filter out names where the second word is 'x'

# %%
sample_for_vision = inat_data.sample(40)

# %%
sample_for_vision
# Out:
#                 id                       observed_on_string observed_on  \
# 1246772  151575301                       2023/03/15 3:42 PM  2023-03-15
# 345094   155993757                      2023-04-21 16:22:34  2023-04-21
# 180938   156354763                2023-04-19 19:18:17-05:00  2023-04-19
# 1175338   75002120  Fri Apr 23 2021 13:32:10 GMT-0700 (PDT)  2021-04-23
# 1052342  129057294                       2022/07/31 4:45 PM  2022-07-31
# 422755    39942755  Fri Mar 13 2020 10:21:07 GMT-0700 (PDT)  2020-03-13
# 727645    21644594  Tue Mar 26 2019 14:51:33 GMT-0700 (PDT)  2019-03-26
# 1530404   51575450  Wed Jul 01 2020 08:12:45 GMT-0500 (CDT)  2020-07-01
# 1289354   13208848  Fri May 25 2018 12:33:33 GMT-0400 (EDT)  2018-05-25
# 1722419  117539744                      2022/05/15 11:24 AM  2022-05-15
# 101935    74313742                2021-04-17 7:19:52 PM CDT  2021-04-17
# 1154908   53151372                   2020/07/13 7:45 AM PDT  2020-07-13
# ...

# %%
urls = list(sample_for_vision.image_url)

# %%
flower_present_list = []
color_list = []
conf_list = []
for idx in range(len(urls)):
    response = client.chat.completions.create(
        model="gpt-4-vision-preview",
        messages=[
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": "Reply to this with a three-word answer, separated onto three lines (one word per line). Please don't break the format. The first line should indicate 'YES' or 'NO' to answer whether there is a flower present. The second line should be one word from the following list, to best describe the flower color in the photo: ['blue', 'brown', 'green', 'orange', 'pink', 'purple', 'red', 'white', 'yellow','unknown','nan']. The flowers might not match these categories perfectly. Do the best you can. If in doubt, choose 'unknown'. The third line should indicate your confindence level in your assessment -- it should either be LOW, MEDIUM, or HIGH."},
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": urls[idx],
                        },
                    },
                ],
            }
        ],
        max_tokens=300,
    )
    flower_present, color, conf = response.choices[0].message.content.split()
    flower_present_list.append(flower_present)
    color_list.append(color)
    conf_list.append(conf)
    time.sleep(0.5)
    if not idx%5:
        print(idx)
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35

# %%
conf_list
# Out:
# ['HIGH',
#  'MEDIUM',
#  'HIGH',
#  'MEDIUM',
#  'HIGH',
#  'HIGH',
#  'MEDIUM',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'MEDIUM',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'MEDIUM',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH',
#  'HIGH']

# %%
gpt_color_labels = pd.DataFrame([urls,[i.lower() for i in color_list],flower_present_list,conf_list],index=['image_url','gpt_color','flower_present','confidence']).T

# %%
gpt_color_labels
# Out:
#                                             image_url gpt_color  \
# 0   https://inaturalist-open-data.s3.amazonaws.com...    purple
# 1   https://inaturalist-open-data.s3.amazonaws.com...      blue
# 2   https://inaturalist-open-data.s3.amazonaws.com...     white
# 3   https://inaturalist-open-data.s3.amazonaws.com...     brown
# 4   https://inaturalist-open-data.s3.amazonaws.com...     white
# 5   https://static.inaturalist.org/photos/63423232...    yellow
# 6   https://inaturalist-open-data.s3.amazonaws.com...     green
# 7   https://inaturalist-open-data.s3.amazonaws.com...     white
# 8   https://inaturalist-open-data.s3.amazonaws.com...     white
# 9   https://inaturalist-open-data.s3.amazonaws.com...     white
# 10  https://static.inaturalist.org/photos/12143911...     white
# 11  https://inaturalist-open-data.s3.amazonaws.com...     white
# 12  https://inaturalist-open-data.s3.amazonaws.com...      pink
# 13  https://inaturalist-open-data.s3.amazonaws.com...    yellow
# ...

# %%
gpt_color_labels.to_csv('../gpt_vision_testing_validation2.csv',index=False)

# %%
flower_present_list
# Out:
# ['YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES']

# %%
urls[2]
# Out:
# 'https://inaturalist-open-data.s3.amazonaws.com/photos/62573852/medium.jpeg'

# %%
color_list
# Out:
# ['white']

# %%
urls[2]
# Out:
# 'https://inaturalist-open-data.s3.amazonaws.com/photos/62573852/medium.jpeg'
